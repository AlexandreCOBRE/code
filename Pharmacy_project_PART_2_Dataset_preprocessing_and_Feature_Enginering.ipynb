# %% [markdown]
# # In this Notebook, the focus is on encoding all variables that are in string form and converting them into numeric variables. It is important to highlight that in this notebook, we analyzed the dataset obtained in the previous notebook from part 1: (Pharmacy project - PART 1_Dataset preprocessing (Merge and feature Enginering.ipynb)

# %%
# Step by step:
# Step 1: Import the merged database in the previous notebook
# Step 2: Encoding all strings into numeric variables
# Step 3: Downloading the combined datasets

# %% [markdown]
# # Step 1: Import the merged database in the previous notebook

# %%
# Step 1: Import the merged database in the previous notebook

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c69442ae-41ee-4547-9a20-cc82f4ab349d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c69442ae-41ee-4547-9a20-cc82f4ab349d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Step 2: Encoding all strings into numeric variables

# %%
# Passo 2: Lendo o dataset
import pandas as pd
df1 = pd.read_csv("combined_datasets.csv")
display (df1)

# %%
# String Variable 1: Sexo
df1["sexo paciente"] = df1["sexo paciente"].replace(["Feminino", "Masculino"], [0, 1])

# %%
df1
# Out:
#         sexo paciente  idade estado do atendimento data do atendimento  \
# 0                   1   49.0                 Ceará          2021-01-27
# 1                   1   43.0          Minas Gerais          2021-01-10
# 2                   0   22.0                Paraná          2021-01-09
# 3                   0   39.0                Paraná          2021-01-06
# 4                   0   44.0                 Ceará          2021-01-25
# ...               ...    ...                   ...                 ...
# 3325562             1   33.0        Rio de Janeiro          2021-06-15
# 3325563             0   24.0             São Paulo          2021-06-15
# 3325564             1   39.0             São Paulo          2021-06-23
# 3325565             1   52.0             São Paulo          2021-06-19
# 3325566             1   75.0                Paraná          2021-06-15
#
#         paciente fez triagem covid? data de inÍcio dos sintomas  \
# ...

# %%
# String Variable 2: paciente fez triagem covid?
df1["paciente fez triagem covid?"] = df1["paciente fez triagem covid?"].replace(["Sim", "Não"], [0, 1])

# %%
df1
# Out:
#         sexo paciente  idade estado do atendimento data do atendimento  \
# 0                   1   49.0                 Ceará          2021-01-27
# 1                   1   43.0          Minas Gerais          2021-01-10
# 2                   0   22.0                Paraná          2021-01-09
# 3                   0   39.0                Paraná          2021-01-06
# 4                   0   44.0                 Ceará          2021-01-25
# ...               ...    ...                   ...                 ...
# 3325562             1   33.0        Rio de Janeiro          2021-06-15
# 3325563             0   24.0             São Paulo          2021-06-15
# 3325564             1   39.0             São Paulo          2021-06-23
# 3325565             1   52.0             São Paulo          2021-06-19
# 3325566             1   75.0                Paraná          2021-06-15
#
#          paciente fez triagem covid? data de inÍcio dos sintomas  \
# ...

# %%
# String Variable 3: paciente com dor de garganta?
df1["paciente com dor de garganta?"] = df1["paciente com dor de garganta?"].replace(["Sim", "Não", "Não Informado"], [0, 1, 2])

# %%
df1["paciente com dor de garganta?"]
# Out:
# 0          2
# 1          2
# 2          0
# 3          2
# 4          2
#           ..
# 3325562    2
# 3325563    2
# 3325564    0
# 3325565    1
# 3325566    2
# Name: paciente com dor de garganta?, Length: 3325567, dtype: int64

# %%
# String Variable 4: # pacient com tosse?
df1["pacient com tosse?"] = df1["pacient com tosse?"].replace(["Sim", "Não", "Não Informado"], [0, 1, 2])

# %%
df1["pacient com tosse?"]
# Out:
# 0          2
# 1          2
# 2          1
# 3          2
# 4          2
#           ..
# 3325562    2
# 3325563    2
# 3325564    1
# 3325565    1
# 3325566    2
# Name: pacient com tosse?, Length: 3325567, dtype: int64

# %%
# String Variable 5: paciente com coriza?
df1["paciente com coriza?"] = df1["paciente com coriza?"].replace(["Sim", "Não", "Não Informado"], [0, 1, 2])

# %%
df1["paciente com coriza?"]
# Out:
# 0          2
# 1          2
# 2          1
# 3          2
# 4          2
#           ..
# 3325562    2
# 3325563    2
# 3325564    0
# 3325565    1
# 3325566    2
# Name: paciente com coriza?, Length: 3325567, dtype: int64

# %%
# String Variable 6: # paciente com diarréia?
df1["paciente com diarréia?"] = df1["paciente com diarréia?"].replace(["Sim", "Não", "Não Informado"], [0, 1, 2])

# %%
df1["paciente com diarréia?"]
# Out:
# 0          2
# 1          2
# 2          0
# 3          2
# 4          2
#           ..
# 3325562    2
# 3325563    2
# 3325564    1
# 3325565    2
# 3325566    2
# Name: paciente com diarréia?, Length: 3325567, dtype: int64

# %%
# String Variable 7: # paciente com pressão persistente no tórax(peito)?
df1["paciente com pressão persistente no tórax(peito)?"] = df1["paciente com pressão persistente no tórax(peito)?"].replace(["Sim", "Não", "Não Informado"], [0, 1, 2])

# %%
df1["paciente com pressão persistente no tórax(peito)?"]
# Out:
# 0          2
# 1          2
# 2          1
# 3          2
# 4          2
#           ..
# 3325562    2
# 3325563    2
# 3325564    1
# 3325565    1
# 3325566    2
# Name: paciente com pressão persistente no tórax(peito)?, Length: 3325567, dtype: int64

# %%
# String Variable 8:paciente com febre?
df1["paciente com febre?"] = df1["paciente com febre?"].replace(["Sim", "Não", "Não Informado"], [0, 1, 2])

# %%
df1["paciente com febre?"]
# Out:
# 0          2
# 1          2
# 2          0
# 3          2
# 4          2
#           ..
# 3325562    2
# 3325563    2
# 3325564    1
# 3325565    1
# 3325566    2
# Name: paciente com febre?, Length: 3325567, dtype: int64

# %%
# String Variable 9:paciente com sintomas respiratórios?
df1["paciente com sintomas respiratórios?"] = df1["paciente com sintomas respiratórios?"].replace(["Sim", "Não", "Não Informado"], [0, 1, 2])

# %%
df1["paciente com sintomas respiratórios?"]
# Out:
# 0          2
# 1          2
# 2          1
# 3          2
# 4          2
#           ..
# 3325562    2
# 3325563    2
# 3325564    1
# 3325565    1
# 3325566    2
# Name: paciente com sintomas respiratórios?, Length: 3325567, dtype: int64

# %%
# String Variable 10:teste covid antígeno
df1["teste covid antígeno"] = df1["teste covid antígeno"].replace(["Sim", "Não"], [1, 0])

# %%
df1["teste covid antígeno"]
# Out:
# 0          0
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 3325562    1
# 3325563    1
# 3325564    0
# 3325565    0
# 3325566    1
# Name: teste covid antígeno, Length: 3325567, dtype: int64

# %%
# String Variable 11:Fabricante
df1["fabricante"] = df1["fabricante"].replace(["Acro Biotech", "ECO Diagnóstica", "Abbott", "Biocredit", "Inativo"], [0, 1, 2, 3, 4])

# %%
df1["fabricante"]
# Out:
# 0                   NaN
# 1                     1
# 2                     1
# 3                     2
# 4                     3
#                ...
# 3325562    MedLevensohn
# 3325563               2
# 3325564             NaN
# 3325565             NaN
# 3325566               2
# Name: fabricante, Length: 3325567, dtype: object

# %%
# String Variable 12:teste covid antígeno
df1["teste covid antígeno"] = df1["teste covid antígeno"].replace(["Sim", "Não"], [1, 0])

# %%
df1["teste covid antígeno"]
# Out:
# 0          0
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 3325562    1
# 3325563    1
# 3325564    0
# 3325565    0
# 3325566    1
# Name: teste covid antígeno, Length: 3325567, dtype: int64

# %%
# String Variable 13:resultado do antígeno
df1["resultado do antígeno"] = df1["resultado do antígeno"].replace(["Não Reagente (Negativo)", "Reagente (Positivo)", "REAGENTE; NÃO REAGENTE"], [0, 1, 2])

# %%
df1["resultado do antígeno"]
# Out:
# 0          NaN
# 1            0
# 2            0
# 3            0
# 4            0
#           ...
# 3325562      0
# 3325563      0
# 3325564    NaN
# 3325565    NaN
# 3325566      0
# Name: resultado do antígeno, Length: 3325567, dtype: object

# %%
# String Variable 14:resultado igg
df1["resultado igg"] = df1["resultado igg"].replace(["Não Reagente (Negativo)", "Reagente (Positivo)"], [0, 1])

# %%
df1["resultado igg"]
# Out:
# 0            0
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 3325562    NaN
# 3325563    NaN
# 3325564    NaN
# 3325565      1
# 3325566    NaN
# Name: resultado igg, Length: 3325567, dtype: object

# %%
# String Variable 15:resultado igm
df1["resultado igm"] = df1["resultado igm"].replace(["Não Reagente (Negativo)", "Reagente (Positivo)"], [0, 1])

# %%
df1["resultado igm"]
# Out:
# 0            0
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#           ...
# 3325562    NaN
# 3325563    NaN
# 3325564    NaN
# 3325565      0
# 3325566    NaN
# Name: resultado igm, Length: 3325567, dtype: object

# %%
df1
# Out:
#         sexo paciente  idade estado do atendimento data do atendimento  \
# 0                   1   49.0                 Ceará          2021-01-27
# 1                   1   43.0          Minas Gerais          2021-01-10
# 2                   0   22.0                Paraná          2021-01-09
# 3                   0   39.0                Paraná          2021-01-06
# 4                   0   44.0                 Ceará          2021-01-25
# ...               ...    ...                   ...                 ...
# 3325562             1   33.0        Rio de Janeiro          2021-06-15
# 3325563             0   24.0             São Paulo          2021-06-15
# 3325564             1   39.0             São Paulo          2021-06-23
# 3325565             1   52.0             São Paulo          2021-06-19
# 3325566             1   75.0                Paraná          2021-06-15
#
#          paciente fez triagem covid? data de inÍcio dos sintomas  \
# ...

# %%
# Baixando os datasets com replace
df1.to_csv('combined_replaced.csv', index=False)

# %%
df1
# Out:
#         sexo paciente  idade estado do atendimento data do atendimento  \
# 0                   1   49.0                 Ceará          2021-01-27
# 1                   1   43.0          Minas Gerais          2021-01-10
# 2                   0   22.0                Paraná          2021-01-09
# 3                   0   39.0                Paraná          2021-01-06
# 4                   0   44.0                 Ceará          2021-01-25
# ...               ...    ...                   ...                 ...
# 3325562             1   33.0        Rio de Janeiro          2021-06-15
# 3325563             0   24.0             São Paulo          2021-06-15
# 3325564             1   39.0             São Paulo          2021-06-23
# 3325565             1   52.0             São Paulo          2021-06-19
# 3325566             1   75.0                Paraná          2021-06-15
#
#          paciente fez triagem covid? data de inÍcio dos sintomas  \
# ...

# %%
# Eliminando novas variáveis
df2 = df1.drop("se verificada qual a oximetria do paciente?", axis = 1)

# %%
df2 = df2.drop("Paciente teve contato próximo ou domiciliar em caso confirmado para COVID-19?", axis = 1)

# %%
df2
# Out:
#         sexo paciente  idade estado do atendimento data do atendimento  \
# 0                   1   49.0                 Ceará          2021-01-27
# 1                   1   43.0          Minas Gerais          2021-01-10
# 2                   0   22.0                Paraná          2021-01-09
# 3                   0   39.0                Paraná          2021-01-06
# 4                   0   44.0                 Ceará          2021-01-25
# ...               ...    ...                   ...                 ...
# 3325562             1   33.0        Rio de Janeiro          2021-06-15
# 3325563             0   24.0             São Paulo          2021-06-15
# 3325564             1   39.0             São Paulo          2021-06-23
# 3325565             1   52.0             São Paulo          2021-06-19
# 3325566             1   75.0                Paraná          2021-06-15
#
#          paciente fez triagem covid? data de inÍcio dos sintomas  \
# ...

# %%
df2 = df2.drop("se verificada qual a temperatura do paciente?", axis = 1)

# %%
df2
# Out:
#         sexo paciente  idade estado do atendimento data do atendimento  \
# 0                   1   49.0                 Ceará          2021-01-27
# 1                   1   43.0          Minas Gerais          2021-01-10
# 2                   0   22.0                Paraná          2021-01-09
# 3                   0   39.0                Paraná          2021-01-06
# 4                   0   44.0                 Ceará          2021-01-25
# ...               ...    ...                   ...                 ...
# 3325562             1   33.0        Rio de Janeiro          2021-06-15
# 3325563             0   24.0             São Paulo          2021-06-15
# 3325564             1   39.0             São Paulo          2021-06-23
# 3325565             1   52.0             São Paulo          2021-06-19
# 3325566             1   75.0                Paraná          2021-06-15
#
#          paciente fez triagem covid? data de inÍcio dos sintomas  \
# ...

# %%
df2 = df2.drop("paciente teve contato próximo ou domiciliar em caso confirmado para covid-19?", axis = 1)

# %%
df2
# Out:
#         sexo paciente  idade estado do atendimento data do atendimento  \
# 0                   1   49.0                 Ceará          2021-01-27
# 1                   1   43.0          Minas Gerais          2021-01-10
# 2                   0   22.0                Paraná          2021-01-09
# 3                   0   39.0                Paraná          2021-01-06
# 4                   0   44.0                 Ceará          2021-01-25
# ...               ...    ...                   ...                 ...
# 3325562             1   33.0        Rio de Janeiro          2021-06-15
# 3325563             0   24.0             São Paulo          2021-06-15
# 3325564             1   39.0             São Paulo          2021-06-23
# 3325565             1   52.0             São Paulo          2021-06-19
# 3325566             1   75.0                Paraná          2021-06-15
#
#          paciente fez triagem covid? data de inÍcio dos sintomas  \
# ...

# %%
df2.info
# Out:
# <bound method DataFrame.info of         sexo paciente  idade estado do atendimento data do atendimento  \
# 0                   1   49.0                 Ceará          2021-01-27
# 1                   1   43.0          Minas Gerais          2021-01-10
# 2                   0   22.0                Paraná          2021-01-09
# 3                   0   39.0                Paraná          2021-01-06
# 4                   0   44.0                 Ceará          2021-01-25
# ...               ...    ...                   ...                 ...
# 3325562             1   33.0        Rio de Janeiro          2021-06-15
# 3325563             0   24.0             São Paulo          2021-06-15
# 3325564             1   39.0             São Paulo          2021-06-23
# 3325565             1   52.0             São Paulo          2021-06-19
# 3325566             1   75.0                Paraná          2021-06-15
#
#          paciente fez triagem covid? data de inÍcio dos sintomas  \
# ...

# %%
# Realizando novos raplaces

# variable 10:teste covid anticorpo
df2["teste covid anticorpo"] = df2["teste covid anticorpo"].replace(["Sim", "Não"], [1, 0])

# %%
# variable 11:Fabricante anticorpo
df2["fabricante.1"] = df2["fabricante.1"].replace(["Acro Biotech", "ECO Diagnóstica", "Abbott", "Biocredit", "Inativo", "Lepu", "MedLevensohn", "Newscen"], [0, 1, 2, 3, 4, 5, 6, 7])

# %%
df2.info
# Out:
# <bound method DataFrame.info of         sexo paciente  idade estado do atendimento data do atendimento  \
# 0                   1   49.0                 Ceará          2021-01-27
# 1                   1   43.0          Minas Gerais          2021-01-10
# 2                   0   22.0                Paraná          2021-01-09
# 3                   0   39.0                Paraná          2021-01-06
# 4                   0   44.0                 Ceará          2021-01-25
# ...               ...    ...                   ...                 ...
# 3325562             1   33.0        Rio de Janeiro          2021-06-15
# 3325563             0   24.0             São Paulo          2021-06-15
# 3325564             1   39.0             São Paulo          2021-06-23
# 3325565             1   52.0             São Paulo          2021-06-19
# 3325566             1   75.0                Paraná          2021-06-15
#
#          paciente fez triagem covid? data de inÍcio dos sintomas  \
# ...

# %% [markdown]
# # Step 3: Downloading the combined datasets

# %%
# Step 3: Downloading the combined datasets
df2.to_csv('combined_replaced_20features_replec2.csv', index=False)
